# %%
import json

# %%
fd = open("Store_Data.json",'r')
r = fd.read()
fd.close()
Products = json.loads(r)
print("Welcome to shop")
ui_prod = input("Enter the product Id: ")
ui_qn = int(input("Enter the quantity of the Product: "))
for i in Products.keys():
    
    while ui_prod == i:
        
        if ui_qn <= Products[i]["qn"]:
            print("****************************************")
            print(" product:",Products[ui_prod]['name'])
            print(" price:",Products[ui_prod]['pr'])
            print(" category:",Products[ui_prod]['category'])
            print(" Discount:",Products[ui_prod]['Discount'])
            print("****************************************")
            print("----------BILLING DETAILS:---------- ")
            print("Total Amount: ",Products[ui_prod]['pr']*ui_qn)
            print("Enjoy Your Day")
            print("Thank You. Visit Again")
            print("**********************************")
            Products[ui_prod]["qn"] = Products[ui_prod]["qn"]-ui_qn
        else:
            print("Sorry. Stock of product you enterd is: ",Products[ui_prod]['qn'],"\nPlease accept our apologies for this inconvenience")
        break
if ui_prod not in Products.keys():
    print("Sorry. No product found for ID: ",ui_prod,"\Please enter valid product ID")
# Out:
# Welcome to shop
# Enter the product Id: 1002
# Enter the quantity of the Product: 2
# ****************************************
#  product: Milk Cake
#  price: 800
#  category: Food
#  Discount: 0%
# ****************************************
# ----------BILLING DETAILS:----------
# Total Amount:  1600
# Enjoy Your Day
# Thank You. Visit Again
# **********************************

# %%
js = json.dumps(Products)
fd = open("Products.json",'w')
fd.write(js)
fd.close()
## The sold items information is stored on sales.json
fd = open("sales.json",'r')
trans = fd.read()
fd.close()
sales = json.loads(trans)
num = len(sales)+1
sales[num] = {'prod':ui_prod, 'qn' : ui_qn, 'amount': Products[ui_prod]['pr'] * ui_qn}
sale = json.dumps(sales)
fd = open("sales.json",'w')
fd.write(sale)
fd.close()

# %%
Products
# Out:
# {'1001': {'name': 'Choco Cake',
#   'qn': 34,
#   'pr': 100,
#   'category': 'Food',
#   'Discount': '1%'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 98,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1003': {'name': 'Drink',
#   'pr': 85,
#   'qn': 100,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1004': {'name': 'Candy',
#   'pr': 5,
#   'qn': 1000,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1005': {'name': 'Pen',
#   'pr': 20,
#   'qn': 100,
#   'category': 'Stationary',
#   'Discount': '0.5%'},
#  '1006': {'name': 'Phone',
#   'pr': 50000,
#   'qn': 10,
#   'category': 'Electonics',
#   'Discount': '7%'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'category': 'Electonics',
#   'Discount': '3%'},
#  '1008': {'name': 'Case',
#   'pr': 599,
#   'qn': 5,
#   'category': 'Accessories',
#   'Discount': '1%'},
#  '1009': {'name': 'Keyboard',
#   'pr': 1999,
#   'qn': 10,
#   'category': 'Electonics',
#   'Discount': '3%'},
# ...

# %% [markdown]
# ## updated inventory

# %%
sales = {1 : {'prod':ui_prod, 'qn':ui_qn, 'amount':Products[ui_prod]['pr']*ui_qn}}
sal = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sal)
fd.close()
