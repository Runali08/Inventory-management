# %%
import json

# %%
Store_Data= { "1001": {"name": "Choco Cake","qn": 34,"pr": 100,"category": "Food","Discount": "1%"},
              "1002": {"name": "Milk Cake","pr": 800,"qn": 100,"category":"Food", "Discount":"0%"},
              "1003": {"name": "Drink", "pr": 85, "qn": 100, "category":"Food", "Discount":"0%"},
              "1004": {"name": "Candy", "pr": 5, "qn": 1000, "category":"Food", "Discount":"0%"},
              "1005": {"name": "Pen", "pr": 20, "qn": 100, "category":"Stationary", "Discount":"0.5%"},
              "1006": {"name": "Phone", "pr": 50000, "qn": 10, "category":"Electonics", "Discount":"7%"},
              "1007": {"name": "Mic", "pr": 1500, "qn": 0, "category":"Electonics", "Discount":"3%"},
              "1008": {"name": "Case", "pr": 599, "qn": 5,"category":"Accessories", "Discount":"1%"}, 
              "1009": {"name": "Keyboard", "pr": 1999, "qn": 10,"category":"Electonics", "Discount":"3%"},
              "1010": {"name": "Poster", "pr": 24.0, "qn": 56,"category":"Accessories", "Discount":"1%"},
              "1011": {"name": "Orange", "pr": 56.89, "qn": 8,"category":"Food", "Discount":"0%"}, 
              "1012": {"name": "Teddy", "pr": 67.0, "qn": 700,"category":"Toy", "Discount":"1%"},
              "1013": {"name": "T-Shirt", "pr": 45.0, "qn": 0,"category":"Cloth", "Discount":"1%"},
              "1014": {"name": "Villain Perfume men", "price": 555, "quan": 230, "category":"Accessories", "Discount":"2%" },
              "1015": {"name": "Cadbury Oreo chacolate", "price": 60, "qn": 185,"category":"Food", "Discount":"0%" },
              "1016": {"name": "Betty Croker Pancake", "price": 346, "qn": 190, "category":"Food", "Discount":"0%"}, 
              "1017": {"name": "Parle G Original", "price": 67, "qn": 140, "category":"Food", "Discount":"0.5%"}, 
              "1018": {"name": "Lays Potato Chips", "price": 30, "qn": 450,"category":"Food", "Discount":"0%"},
              "1019": {"name": "Bingo! Mad Angle", "price": 25, "qn": 440, "category":"Food", "Discount":"0.2%"},
              "1020": {"name": "Kellogg's pringles", "price": 85, "qn": 400, "category":"Food", "Discount":"1%"},
              "1021": {"name": "Dorito's Nacho Chips", "price": 90, "qn": 360, "category":"Food", "Discount":"1%"},
              "1022": {"name": "Thums Up Soft Drink", "price": 40, "qn": 60, "category":"Food", "Discount":"0%"},
              "1023": {"name": "Svami Soda Water", "price": 55, "qn": 70,"category":"Food", "Discount":"0%"}, 
              "1024": {"name": "Coca-Cola", "price": 65, "qn": 60, "category":"Food", "Discount":"1%"},
              "1025": {"name": "Sprite Lime Flavor", "price": 89, "qn": 40, "category":"Food", "Discount":"0%"}, 
              "1026": {"name": "Colgate Maxfresh", "price": 215, "qn": 55, "category":"Food", "Discount":"1%"},
              "1027": {"name": "Pepsodent Gum Care", "price": 300, "qn": 150, "category":"Food", "Discount":"0.8%"},
              "1028": {"name": "Dabur Amla Hair Oil", "price": 247, "qn": 100,"category":"Food", "Discount":"1%"},
              "1029": {"name": "Nivea Men Face Wash", "price": 149, "qn": 98, "category":"Skin Care", "Discount":"2%"}, 
              "1030": {"name": "Himalaya Herbal Face wash", "price": 104, "qn": 200, "category":"Skin Care", "Discount":"0%"},
              "1031": {"name": "Himalaya Baby Powder", "price": 243, "qn": 150, "category":"Skin Care", "Discount":"2%"}, 
              "1032": {"name": "Nivea Talcum Powder", "price": 199, "qn": 120,"category":"Skin Care", "Discount":"2%"},
              "1033": {"name": "Fogg Xtremo Scent", "price": 299, "quan": 155, "category":"Accessories", "Discount":"2%"}, 
              }

# %%
js = json.dumps(Store_Data)

# %%
fd = open("Store_Data.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# ## Read data from json

# %%
fd = open("Store_Data.json",'r')
r = fd.read()
fd.close()

Store_Data= json.loads(r)

# %%
Store_Data
# Out:
# {'1001': {'name': 'Choco Cake',
#   'qn': 34,
#   'pr': 100,
#   'category': 'Food',
#   'Discount': '1%'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1003': {'name': 'Drink',
#   'pr': 85,
#   'qn': 100,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1004': {'name': 'Candy',
#   'pr': 5,
#   'qn': 1000,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1005': {'name': 'Pen',
#   'pr': 20,
#   'qn': 100,
#   'category': 'Stationary',
#   'Discount': '0.5%'},
#  '1006': {'name': 'Phone',
#   'pr': 50000,
#   'qn': 10,
#   'category': 'Electonics',
#   'Discount': '7%'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'category': 'Electonics',
#   'Discount': '3%'},
#  '1008': {'name': 'Case',
#   'pr': 599,
#   'qn': 5,
#   'category': 'Accessories',
#   'Discount': '1%'},
#  '1009': {'name': 'Keyboard',
#   'pr': 1999,
#   'qn': 10,
#   'category': 'Electonics',
#   'Discount': '3%'},
# ...

# %% [markdown]
# ## Add new inventory

# %%
prod_id = str(input("Enter product id:"))
name = str(input("Enter name:"))
pr = int(input("Enter price:"))
qn = int(input("Enter quantity:"))
category = str(input("Enter category:"))
Discount = str(input("Enter Discount:"))
 
Store_Data[prod_id] = {'name': name, 'pr': pr, 'qn': qn, 'category':category,'Discount':Discount}

js = json.dumps(Store_Data)

fd = open("Store_Data.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1034
# Enter name:Head phones
# Enter price:1200
# Enter quantity:23
# Enter category:Electronics
# Enter Discount:10%

# %%
Store_Data
# Out:
# {'1001': {'name': 'Choco Cake',
#   'qn': 34,
#   'pr': 100,
#   'category': 'Food',
#   'Discount': '1%'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1003': {'name': 'Drink',
#   'pr': 85,
#   'qn': 100,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1004': {'name': 'Candy',
#   'pr': 5,
#   'qn': 1000,
#   'category': 'Food',
#   'Discount': '0%'},
#  '1005': {'name': 'Pen',
#   'pr': 20,
#   'qn': 100,
#   'category': 'Stationary',
#   'Discount': '0.5%'},
#  '1006': {'name': 'Phone',
#   'pr': 50000,
#   'qn': 10,
#   'category': 'Electonics',
#   'Discount': '7%'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'category': 'Electonics',
#   'Discount': '3%'},
#  '1008': {'name': 'Case',
#   'pr': 599,
#   'qn': 5,
#   'category': 'Accessories',
#   'Discount': '1%'},
#  '1009': {'name': 'Keyboard',
#   'pr': 1999,
#   'qn': 10,
#   'category': 'Electonics',
#   'Discount': '3%'},
# ...
